# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('Titanic.csv')

# %% [markdown]
# 1.Create 5 Plots
# - Make five different visualizations that help understand patterns or trends in the data. Examples:
#
#     • Histogram / distribution plot
#
#     • Box plot
#
#     • Scatter plot
#
#     • Bar chart
#
#     • Correlation heatmap
# - Each plot should include a clear title and axis labels.
#
# 2.Write 5 Insights
#
# - From your analysis, write five insights. Each insight should:
#
#     • Be based on one of your plots
#
#     • Describe a pattern, relationship, or notable observation
#
#     • Be written in a clear, concise sentence
#
# 3.Add Short Notes
# - For each of the five plots, write 1–2 short sentences explaining:
#     • Why you chose that plot
#
#     • What it reveals about the data

# %%
sns.countplot(x=df['Pclass'], y=df['Survived'])
sns.scatterplot(x=df['PetalLengthCm'], y=df['PetalWidthCm'],palette='rocket' , hue=df['Species'])
sns.histplot(df['PetalLengthCm'], bins=50, kde=True, color="navy", edgecolor="black")
sns.boxplot(x = df['Species'], y = df['PetalLengthCm'], data = df, palette="rocket")
sns.barplot(x=df['SepalLengthCm'].mean() , y=df['Species'] , palette='rocket')
sns.pairplot(data=df, hue='Species', palette='rocket')

# %%
sns.histplot(df['Fare'], bins=50, kde=True, color="navy", edgecolor="black")
plt.title('Fare Distribution')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Analysis of Fare Distribution**
#
# **Left-Skewed Distribution (skewness = 4.78)**
#
# **The fare distribution shows the following:**
#
# - Most passengers paid between 5 and 30 (approximately) → That's why the poles there are so high.
#
# - As we move to the right, the fare increases, but we find very few people paying over 100, over 200, and very rarely over 500.
#
# - This means that a very small number of people were in luxurious cabins with very high fares.
#
# **Outliers in the Distribution:**
#
# - There are many outliers because a very small number of people paid huge fares while most paid small amounts. This means that a very small number of people are wealthy, and the rest are from the general public, the poor.

# %%
sns.boxplot(x = df['Survived'], y = df['Age'], data = df, palette="rocket")
plt.title('Survived By Age')
plt.xlabel('Survived')
plt.ylabel('Age')
plt.show()
# Out:
# /tmp/ipython-input-1248649756.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = df['Survived'], y = df['Age'], data = df, palette="rocket")

# %% [markdown]
# **The age of passengers diagram shows :**
#
# **The median is equal in both the survival and non-survival cases.**
#
# - For those who survived -> (1) :
#
#   - moderate median age nearly with fairly wide interquartile range.
#   - we'll need to increase the coefficient (1.5) by a much larger value.
#
# - For those who are not survived -> (0) :
#
#   - has a farily wide interquartile range
#   - a large amount of data are close to the max value, so we'll need to increase the coefficient (1.5) by a much larger value.

# %%
ax = sns.countplot(x=df['Pclass'], hue=df['Survived'] , data = df, palette="rocket")
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2, height,
                f'{height/len(df)*100:.2f}%', ha='center', va='bottom', fontsize=10, color='black')
plt.title('Pclass By Survived')
plt.xlabel('Pclass')
plt.ylabel('Survived')
plt.show()

# %% [markdown]
# **Analysis of Survived by Pclass**
#
# - for first class :
#
#   - 24.2% of passengers are in the first class -> (216)
#     - 8.98% -> Not Survived -> (80 passengers)
#     - 15.26% -> Survived -> (136 passengers)
#   - first class is the highest place of the ship , so it is possible for them to rescue easier than others
#
# - for second class (lowest amount of passengers) :
#
#   - 20.7% of passengers are in the second class -> (184 passengers)
#     - 10.89% -> Not Survived -> (97 passengers)
#     - 9.76% -> Survived -> (87 passengers)
#   - the percentage of the survived and unsurvived passengers is very closer to each other.
#
# - for third class (highest amount of passengers) :
#   - 55.1% of passengers are in the third class -> (491 passengers)
#     - 41.75% -> Not Survived -> (372 passengers)
#     - 13.36% -> Survived -> (119 passengers)
#   - it is clearly hard to survive as you are in the lowest level of the ship so it is logical to get this result
#
# **Total Number of Survived Passengers = 342** \
# **Total Number of Not Survived Passengers = 549**
#
# **NOTE : number of passengers is calculated based on the whole number of rows (891)**

# %%
sns.scatterplot(x=df['Age'], y=df['Fare'],palette='rocket' , hue=df['Survived'])
plt.title('Parch By Pclass')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# **Age-Survival Relationship:**
#
# 1. Children (Age 0-10): High survival across all classes (orange cluster at bottom-left)
#
# 2. Young Adults (20-30): Mixed survival, class-dependent
#
# 3. Middle-aged (30-50): Better survival in 1st class
#
# 4. Elderly (60+): Lower survival rates overall
#
# **Fare-Survival Relationship:**
#
# 1. Clear positive correlation: Higher fare → Higher survival chance
#
# 2. Threshold effect: Above certain fare thresholds, survival increases dramatically
#
# 3. Within-class variation: Even within same class, higher fare = better survival

# %%
satisfaction_counts = df['Embarked'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(satisfaction_counts,
            labels=satisfaction_counts.index,
            autopct='%1.1f%%',
            startangle=90,
            colors=plt.cm.Dark2.colors)
plt.title(f"Distribution of Embarked")
plt.axis('equal')
plt.show()

# %% [markdown]
# **Embarked Analysis**
#
# There are three types of starting location (embarked) :
#
# - S with the highest percentage (72.4%)
# - C with percentage of 18.9%
# - Q with the least percentage (8.7%)
