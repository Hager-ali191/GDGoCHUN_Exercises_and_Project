# %%
# create variables and print their values
name = "hager"
age = 21
print(f"My name is {name} , and I am {age} years old.")

# take input from the user and print it
your_name = input("Let me know about you , what is your name ?")
your_age = input("And your age ?")

# combine two string and print the result
our_name = name + ' ' + your_name
our_age = str(age) + ' ' + your_age

print(f"Our Names are : {our_name} , and our ages are : {our_age}")

# check if number greater than 10
if int(your_age) > 10:
  print("ok good! , you are old.")
else:
  print("what?? I do not expect to talk to a child!?")

# loop printing from 1 to 5
print("according to that , I will teach you numbers from 1 to 5.")
print("let's goooo .....")
for number in range(1,6):
  print(number)

# create a function that print a message
def fun_to_print():
  print("Yeah , It is me talking to you but by a different way.")

fun_to_print()

# create list and print its elements
print("Let's combine our information together")
our_info = [our_name , our_age]
print(our_info)
print("See?")

# create a tuple and access one element
print("Let's try another way")
our_info2 = (name , your_name , age , your_age)
print(our_info2[0])
print("Yeah , I am selfish enough to ignore yours.")

# create a dictionary and print one value
print("Ok no drama , now yours")
our_info3 = {
    'your name' : your_name,
    'name' : name,
    'your age' : your_age,
    'age' : age
}
print(our_info3['your name'])
# Out:
# My name is hager , and I am 21 years old.
# Let me know about you , what is your name ?m
# And your age ?9
# Our Names are : hager m , and our ages are : 21 9
# what?? I do not expect to talk to a child!?
# according to that , I will teach you numbers from 1 to 5.
# let's goooo .....
# 1
# 2
# 3
# 4
# 5
# Yeah , It is me talking to you but by a different way.
# Let's combine our information together
# ['hager m', '21 9']
# See?
# Let's try another way
# hager
# Yeah , I am selfish enough to ignore yours.
# Ok no drama , now yours
# m
